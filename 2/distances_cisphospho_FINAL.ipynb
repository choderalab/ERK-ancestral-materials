# %%
# TODO: plot all distances from paper that have KS test diff. distributions (# let's just look at the most important distances - V186 - L168, T188 - D147, T188 - K149, Y185 - D147, T183-D147)
# in particular plot the Y-D distance

# timetrace of Y-D for WT
# examples of frames with Y-D hydrogen bonds from WT

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('ticks')
sns.set_context('notebook')
import scipy
import matplotlib.patches as mpatches

# %%
distances = np.load('distances2_cisphospho.npy')
dist2 = np.concatenate([x[0] for x in distances])
del distances

# %%
distances = np.load('distances3_cisphospho.npy')
dist3 = np.concatenate([x[0] for x in distances])
del distances

# %%
distances = np.load('distances4_cisphospho.npy')
dist4 = np.concatenate([x[0] for x in distances])
del distances

# %%
distances = np.load('distances5_cisphospho.npy')
dist5 = np.concatenate([x[0] for x in distances])
del distances

# %%
# first most important - D147-Y185

# %%
dist = 53 # Y185 - D147

print(scipy.stats.ks_2samp(dist2[:,dist], dist3[:,dist])[0], scipy.stats.ks_2samp(dist2[:,dist], dist4[:,dist])[0], scipy.stats.ks_2samp(dist2[:,dist], dist5[:,dist])[0])

plt.figure(dpi=300)
sns.distplot(dist2[:,dist]*10, color='green')
sns.distplot(dist3[:,dist]*10, color='blue')
sns.distplot(dist4[:,dist]*10, color='yellow')
sns.distplot(dist5[:,dist]*10, color='black')
plt.xlabel('D147-Y185 distance ($\AA$)')
plt.ylabel('Probability density')
plt.xlim((2,10))
#plt.title('ERK2')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='55N')
patch3 = mpatches.Patch(color='yellow', label='Q103M')
patch4 = mpatches.Patch(color='black', label='55N-Q103M')
plt.legend(handles=[patch1, patch2, patch3, patch4])

plt.show()
# Out:
# 0.11130217455932101 0.2819919560886911 0.210896795438602

# %%
# do only those below 4

# %%
dist = 53

print(len([x for x in dist2[:,dist]*10 if x < 4]) / len(dist2[:,dist]))
print(len([x for x in dist3[:,dist]*10 if x < 4]) / len(dist3[:,dist]))
print(len([x for x in dist4[:,dist]*10 if x < 4]) / len(dist4[:,dist]))
print(len([x for x in dist5[:,dist]*10 if x < 4]) / len(dist5[:,dist]))
# Out:
# 0.017195056956571548
# 0.008840254972396433
# 0.004200535874001253
# 0.0023682534059711983

# %%
dist2.as

# %%
dist = 53 # Y185 - D147

print(scipy.stats.ks_2samp(dist2[:,dist], dist3[:,dist])[0], scipy.stats.ks_2samp(dist2[:,dist], dist4[:,dist])[0], scipy.stats.ks_2samp(dist2[:,dist], dist5[:,dist])[0])

plt.figure(dpi=300)
sns.distplot(≈, color='green')
sns.distplot([x for x in dist3[:,dist]*10 if x < 4], color='blue')
sns.distplot([x for x in dist4[:,dist]*10 if x < 4], color='yellow')
sns.distplot([x for x in dist5[:,dist]*10 if x < 4], color='black')
plt.xlabel('D147-Y185 distance ($\AA$)')
plt.ylabel('Probability density')
plt.xlim((2,5))
#plt.title('ERK2')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='55N')
patch3 = mpatches.Patch(color='yellow', label='Q103M')
patch4 = mpatches.Patch(color='black', label='55N-Q103M')
plt.legend(handles=[patch1, patch2, patch3, patch4])

plt.show()
# Out:
# 0.11130217455932101 0.2819919560886911 0.210896795438602

# %%
dist = 53

plt.figure(dpi=300)
plt.scatter(range(len(dist2[:,dist])), dist2[:,dist]*10, s=0.1)
plt.xlabel('Frame')
plt.ylabel('D147-Y185 distance ($\AA$)')
plt.show()

# %%
# let's just look at the most important distances - V186 - L168, T188 - D147, T188 - K149, Y185 - D147, T183-D147
# these are contact indices: 38,60,61,53,57
# (Y-D done above already)

# %%
dist = 38 # V186 - L168

print(scipy.stats.ks_2samp(dist2[:,dist], dist3[:,dist])[0], scipy.stats.ks_2samp(dist2[:,dist], dist4[:,dist])[0], scipy.stats.ks_2samp(dist2[:,dist], dist5[:,dist])[0])

plt.figure(dpi=300)
sns.distplot(dist2[:,dist]*10, color='green')
sns.distplot(dist3[:,dist]*10, color='blue')
sns.distplot(dist4[:,dist]*10, color='yellow')
sns.distplot(dist5[:,dist]*10, color='black')
plt.xlabel('L168-V186 distance ($\AA$)')
plt.ylabel('Probability density')
plt.xlim((2,10))
#plt.title('ERK2')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='55N')
patch3 = mpatches.Patch(color='yellow', label='Q103M')
patch4 = mpatches.Patch(color='black', label='55N-Q103M')
plt.legend(handles=[patch1, patch2, patch3, patch4])

plt.show()
# Out:
# 0.18669132778823083 0.13406566887963722 0.20214713243596233

# %%
dist = 38

print(1 - len([x for x in dist2[:,dist]*10 if x < 4]) / len(dist2[:,dist]))
print(1 - len([x for x in dist3[:,dist]*10 if x < 4]) / len(dist3[:,dist]))
print(1 - len([x for x in dist4[:,dist]*10 if x < 4]) / len(dist4[:,dist]))
print(1 - len([x for x in dist5[:,dist]*10 if x < 4]) / len(dist5[:,dist]))
# Out:
# 0.41762739892512213
# 0.24067169340083072
# 0.29266172255667544
# 0.2221206485605266

# %%
dist = 57 # T183-D147

print(scipy.stats.ks_2samp(dist2[:,dist], dist3[:,dist])[0], scipy.stats.ks_2samp(dist2[:,dist], dist4[:,dist])[0], scipy.stats.ks_2samp(dist2[:,dist], dist5[:,dist])[0])

plt.figure(dpi=300)
sns.distplot(dist2[:,dist]*10, color='green')
sns.distplot(dist3[:,dist]*10, color='blue')
sns.distplot(dist4[:,dist]*10, color='yellow')
sns.distplot(dist5[:,dist]*10, color='black')
plt.xlabel('D147-T183 distance ($\AA$)')
plt.ylabel('Probability density')
#plt.xlim((2,10))
#plt.title('ERK2')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='55N')
patch3 = mpatches.Patch(color='yellow', label='Q103M')
patch4 = mpatches.Patch(color='black', label='55N-Q103M')
plt.legend(handles=[patch1, patch2, patch3, patch4])

plt.show()
# Out:
# 0.2571560581156438 0.14218830183441206 0.28412490665429535

# %%
# only these two had any populations significantly different from wt

# %%
# 100 conformations with shortest D-Y distance or 100 random samples from frames with < 4A - let's see how many
# trajectories there are

# %%
distances = np.load('distances2_cisphospho.npy')
distances = [x[0] for x in distances]

# %%
trajs = []

for i,traj in enumerate(distances):
    if np.any(traj[:,53] < 0.4):
        trajs.append(i)

# %%
len(trajs) / len(distances)
# Out:
# 0.325

# %%
indexes = []
values = [] 

for i,traj in enumerate(distances):
    for j,frame in enumerate(traj[:,53]):
        if frame < 0.4:
            indexes.append([i,j])
            values.append(frame)

# %%
len(indexes) / len(dist2)
# Out:
# 0.017195056956571548

# %%
from collections import Counter

# %%
Counter(np.array(indexes)[np.argsort(values)[:100]][:,0])
# Out:
# Counter({332: 2,
#          337: 15,
#          543: 9,
#          635: 1,
#          704: 1,
#          724: 1,
#          749: 8,
#          765: 6,
#          780: 5,
#          806: 3,
#          820: 27,
#          927: 22})

# %%
# ok let's do both 100 shortest distances and random 100

# %%
np.array(values)[np.argsort(values)[:100]][0], np.array(values)[np.argsort(values)[:100]][-1]
# Out:
# (0.23552477, 0.25112745)

# %%
np.save('cisphospho_yd_top100', np.array(indexes)[np.argsort(values)][:100])

# %%
np.random.seed(7)
random100 = np.array(indexes)[np.random.choice(range(len(indexes)), 100)]

# %%
np.save('cisphospho_yd_random100', random100)
