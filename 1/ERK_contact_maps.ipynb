# %%
import numpy as np
import matplotlib.pyplot as plt
import mdtraj as md
import seaborn as sns
sns.set_style('ticks')
sns.set_context('paper')

# %%
pwd
# Out:
# '/Users/rafalpwiewiora/repos/ERK'

# %%
erk2_wt = np.load('contact_maps/contact_map_erk2_wt.npy')
erk2_55n = np.load('contact_maps/contact_map_erk2_55n.npy')
erk2_q102m = np.load('contact_maps/contact_map_erk2_q102m.npy')
erk2_55n_q102m = np.load('contact_maps/contact_map_erk2_55n_q102m.npy')

# %%
erk2_wt.shape
# Out:
# (357, 357)

# %%
erk2_55n.shape
# Out:
# (358, 358)

# %%
erk2_55n_wtsize = np.zeros((357,357))

for i in range(357):
    for j in range(357):
        if i >= 54:
            i_ = i+1
        else:
            i_ = i
        if j >= 54:
            j_ = j+1
        else:
            j_ = j
        erk2_55n_wtsize[i,j] = erk2_55n[i_,j_]

# %%
erk2_55n_q102m_wtsize = np.zeros((357,357))

for i in range(357):
    for j in range(357):
        if i >= 54:
            i_ = i+1
        else:
            i_ = i
        if j >= 54:
            j_ = j+1
        else:
            j_ = j
        erk2_55n_q102m_wtsize[i,j] = erk2_55n_q102m[i_,j_]

# %%
# mutant is at 0-index 54

# %%
#sns.set(font_scale=2.5, rc={'figure.figsize':(11.7*1.5,8.27*1.5)})
sns.set_style('ticks')

# %%
plt.figure(dpi=300)
plt.imshow(erk2_wt, cmap='Greys')
cbar = plt.colorbar()
cbar.set_label('Mean contact fraction')
plt.title('ERK2 WT')
plt.xticks(np.arange(0,erk2_wt.shape[0],50))
plt.yticks(np.arange(0,erk2_wt.shape[0],50))
plt.show()

# %%
# I'm making two versions for each - one with changes on both halves, another on only one (only WT on the other)

# %%
# first both for ERK2, then ERK1

# %%
# one half first

# %%
contact_map = erk2_55n_wtsize - erk2_wt

contact_map_ = np.zeros(contact_map.shape)

for i, x in enumerate(contact_map):
    for j, y in enumerate(x):
        if j > i:
            break
        else:
            contact_map_[i,j] = contact_map[i,j]

# if np.max(contact_map_) > np.absolute(np.min(contact_map_)):
#     vmax = np.max(contact_map_)
#     vmin = - vmax
# else:
#     vmin = np.min(contact_map_)
#     vmax = -vmin      

vmin = -1
vmax = 1

plt.figure(dpi=300)
plt.imshow(erk2_wt, cmap='Greys')
plt.imshow(contact_map_, cmap='seismic_r', vmin=vmin, vmax=vmax, alpha=0.85)
plt.xticks(np.arange(0,contact_map.shape[0],50))
plt.yticks(np.arange(0,contact_map.shape[0],50))
cbar = plt.colorbar()
cbar.set_label('Mean contact fraction change')
plt.title('ERK2 55N - WT')
plt.show()

# %%
contact_map = erk2_q102m - erk2_wt

contact_map_ = np.zeros(contact_map.shape)

for i, x in enumerate(contact_map):
    for j, y in enumerate(x):
        if j > i:
            break
        else:
            contact_map_[i,j] = contact_map[i,j]

# if np.max(contact_map_) > np.absolute(np.min(contact_map_)):
#     vmax = np.max(contact_map_)
#     vmin = - vmax
# else:
#     vmin = np.min(contact_map_)
#     vmax = -vmin      

vmin = -1
vmax = 1

plt.figure(dpi=300)
plt.imshow(erk2_wt, cmap='Greys')
plt.imshow(contact_map_, cmap='seismic_r', vmin=vmin, vmax=vmax, alpha=0.85)
plt.xticks(np.arange(0,contact_map.shape[0],50))
plt.yticks(np.arange(0,contact_map.shape[0],50))
cbar = plt.colorbar()
cbar.set_label('Mean contact fraction change')
plt.title('ERK2 Q102M - WT')
plt.show()

# %%
contact_map = erk2_55n_q102m_wtsize - erk2_wt

contact_map_ = np.zeros(contact_map.shape)

for i, x in enumerate(contact_map):
    for j, y in enumerate(x):
        if j > i:
            break
        else:
            contact_map_[i,j] = contact_map[i,j]

# if np.max(contact_map_) > np.absolute(np.min(contact_map_)):
#     vmax = np.max(contact_map_)
#     vmin = - vmax
# else:
#     vmin = np.min(contact_map_)
#     vmax = -vmin      

vmin = -1
vmax = 1

plt.figure(dpi=300)
plt.imshow(erk2_wt, cmap='Greys')
plt.imshow(contact_map_, cmap='seismic_r', vmin=vmin, vmax=vmax, alpha=0.85)
plt.xticks(np.arange(0,contact_map.shape[0],50))
plt.yticks(np.arange(0,contact_map.shape[0],50))
cbar = plt.colorbar()
cbar.set_label('Mean contact fraction change')
plt.title('ERK2 55N-Q102M - WT')
plt.show()

# %%
contact_map = erk2_55n_wtsize - erk2_wt

# contact_map_ = np.zeros(contact_map.shape)

# for i, x in enumerate(contact_map):
#     for j, y in enumerate(x):
#         if j > i:
#             break
#         else:
#             contact_map_[i,j] = contact_map[i,j]

contact_map_ = contact_map

# if np.max(contact_map_) > np.absolute(np.min(contact_map_)):
#     vmax = np.max(contact_map_)
#     vmin = - vmax
# else:
#     vmin = np.min(contact_map_)
#     vmax = -vmin      

vmin = -1
vmax = 1          

plt.figure(dpi=300)
plt.imshow(erk2_wt, cmap='Greys')
plt.imshow(contact_map_, cmap='seismic_r', vmin=vmin, vmax=vmax, alpha=0.85)
plt.xticks(np.arange(0,contact_map.shape[0],50))
plt.yticks(np.arange(0,contact_map.shape[0],50))
cbar = plt.colorbar()
cbar.set_label('Mean contact fraction change')
plt.title('ERK2 55N - WT')
plt.show()

# %%
contact_map = erk2_q102m - erk2_wt

# contact_map_ = np.zeros(contact_map.shape)

# for i, x in enumerate(contact_map):
#     for j, y in enumerate(x):
#         if j > i:
#             break
#         else:
#             contact_map_[i,j] = contact_map[i,j]

contact_map_ = contact_map

# if np.max(contact_map_) > np.absolute(np.min(contact_map_)):
#     vmax = np.max(contact_map_)
#     vmin = - vmax
# else:
#     vmin = np.min(contact_map_)
#     vmax = -vmin      

vmin = -1
vmax = 1          

plt.figure(dpi=300)
plt.imshow(erk2_wt, cmap='Greys')
plt.imshow(contact_map_, cmap='seismic_r', vmin=vmin, vmax=vmax, alpha=0.85)
plt.xticks(np.arange(0,contact_map.shape[0],50))
plt.yticks(np.arange(0,contact_map.shape[0],50))
cbar = plt.colorbar()
cbar.set_label('Mean contact fraction change')
plt.title('ERK2 Q102M - WT')
plt.show()

# %%
contact_map = erk2_55n_q102m_wtsize - erk2_wt

# contact_map_ = np.zeros(contact_map.shape)

# for i, x in enumerate(contact_map):
#     for j, y in enumerate(x):
#         if j > i:
#             break
#         else:
#             contact_map_[i,j] = contact_map[i,j]

contact_map_ = contact_map

# if np.max(contact_map_) > np.absolute(np.min(contact_map_)):
#     vmax = np.max(contact_map_)
#     vmin = - vmax
# else:
#     vmin = np.min(contact_map_)
#     vmax = -vmin      

vmin = -1
vmax = 1          

plt.figure(dpi=300)
plt.imshow(erk2_wt, cmap='Greys')
plt.imshow(contact_map_, cmap='seismic_r', vmin=vmin, vmax=vmax, alpha=0.85)
plt.xticks(np.arange(0,contact_map.shape[0],50))
plt.yticks(np.arange(0,contact_map.shape[0],50))
cbar = plt.colorbar()
cbar.set_label('Mean contact fraction change')
plt.title('ERK2 55N-Q102M - WT')
plt.show()

# %%
########

# %%
# now ERK1

# %%
# insert is at 0-index 51

# %%
erk1_wt = np.load('contact_maps/contact_map_erk1_wt.npy')
erk1_74n = np.load('contact_maps/contact_map_erk1_74n.npy')

# %%
erk1_wt.shape
# Out:
# (352, 352)

# %%
erk1_74n.shape
# Out:
# (353, 353)

# %%
erk1_74n_wtsize = np.zeros((352,352))

for i in range(352):
    for j in range(352):
        if i >= 51:
            i_ = i+1
        else:
            i_ = i
        if j >= 51:
            j_ = j+1
        else:
            j_ = j
        erk1_74n_wtsize[i,j] = erk1_74n[i_,j_]

# %%
plt.figure(dpi=300)
plt.imshow(erk1_wt, cmap='Greys')
cbar = plt.colorbar()
cbar.set_label('Mean contact fraction')
plt.title('ERK1 WT')
plt.show()

# %%
# one half

# %%
contact_map = erk1_74n_wtsize - erk1_wt

contact_map_ = np.zeros(contact_map.shape)

for i, x in enumerate(contact_map):
    for j, y in enumerate(x):
        if j > i:
            break
        else:
            contact_map_[i,j] = contact_map[i,j]

# if np.max(contact_map_) > np.absolute(np.min(contact_map_)):
#     vmax = np.max(contact_map_)
#     vmin = - vmax
# else:
#     vmin = np.min(contact_map_)
#     vmax = -vmin      

vmin = -1
vmax = 1

plt.figure(dpi=300)
plt.imshow(erk2_wt, cmap='Greys')
plt.imshow(contact_map_, cmap='seismic_r', vmin=vmin, vmax=vmax, alpha=0.85)
plt.xticks(np.arange(0,contact_map.shape[0],50))
plt.yticks(np.arange(0,contact_map.shape[0],50))
cbar = plt.colorbar()
cbar.set_label('Mean contact fraction change')
plt.title('ERK1 74N - WT')
plt.show()

# %%
# both halves

# %%
contact_map = erk1_74n_wtsize - erk1_wt

# contact_map_ = np.zeros(contact_map.shape)

# for i, x in enumerate(contact_map):
#     for j, y in enumerate(x):
#         if j > i:
#             break
#         else:
#             contact_map_[i,j] = contact_map[i,j]

contact_map_ = contact_map

# if np.max(contact_map_) > np.absolute(np.min(contact_map_)):
#     vmax = np.max(contact_map_)
#     vmin = - vmax
# else:
#     vmin = np.min(contact_map_)
#     vmax = -vmin      

vmin = -1
vmax = 1          

plt.figure(dpi=300)
plt.imshow(erk2_wt, cmap='Greys')
plt.imshow(contact_map_, cmap='seismic_r', vmin=vmin, vmax=vmax, alpha=0.85)
plt.xticks(np.arange(0,contact_map.shape[0],50))
plt.yticks(np.arange(0,contact_map.shape[0],50))
cbar = plt.colorbar()
cbar.set_label('Mean contact fraction change')
plt.title('ERK1 74N - WT')
plt.show()

# %%
# let's make csv's now of all the contact maps too for easy checking

# %%
mkdir contact_maps_csv

# %%
np.savetxt('contact_maps_csv/erk2_wt.csv', erk2_wt, delimiter=",")

# %%
np.savetxt('contact_maps_csv/erk2_wt_diff_55n.csv', erk2_55n_wtsize - erk2_wt, delimiter=",")

# %%
np.savetxt('contact_maps_csv/erk2_55n.csv', erk2_55n_wtsize, delimiter=",")

# %%
np.savetxt('contact_maps_csv/erk2_wt_diff_q102m.csv', erk2_q102m - erk2_wt, delimiter=",")

# %%
np.savetxt('contact_maps_csv/erk2_q102m.csv', erk2_q102m, delimiter=",")

# %%
np.savetxt('contact_maps_csv/erk2_wt_diff_55n_q102m.csv', erk2_55n_q102m_wtsize - erk2_wt, delimiter=",")

# %%
np.savetxt('contact_maps_csv/erk2_55n_q102m.csv', erk2_55n_q102m_wtsize, delimiter=",")

# %%
np.savetxt('contact_maps_csv/erk1_wt.csv', erk1_wt, delimiter=",")

# %%
np.savetxt('contact_maps_csv/erk1_wt_diff_74n.csv', erk1_74n_wtsize - erk1_wt, delimiter=",")

# %%
np.savetxt('contact_maps_csv/erk1_74n.csv', erk1_74n_wtsize, delimiter=",")

# %%
#####

# %%
# now we want to color structures in PyMOL with the contact changes for ERK2 mutants

# %%
# 55n - wt

# %%
contact_map = erk2_55n_wtsize - erk2_wt

contact_map_ = np.zeros(contact_map.shape)

for i, x in enumerate(contact_map):
    for j, y in enumerate(x):
        if j > i:
            break
        else:
            contact_map_[i,j] = contact_map[i,j]

# %%
# so now for every residue, let's get the sum of absolute changes

# %%
contact_map.shape
# Out:
# (357, 357)

# %%
abs_sum_changes = []

for i in range(len(contact_map)):
    abs_sum_changes.append(np.sum(np.abs(contact_map[i])))

# %%
np.max(abs_sum_changes)
# Out:
# 7.2576279233485277

# %%
sns.set_context('notebook')

# %%
plt.figure(dpi=300)
plt.plot(abs_sum_changes)
plt.xlabel('Residue index')
plt.ylabel('Sum of absolute contact changes')
plt.title('ERK2 55N - WT')
plt.ylim((-0.4,8))
plt.show()

# %%
np.savetxt('erk2_55n_diff_wt_abs_sum_changes', abs_sum_changes)

# %%
# q103m

# %%
contact_map = erk2_q102m - erk2_wt

contact_map_ = np.zeros(contact_map.shape)

for i, x in enumerate(contact_map):
    for j, y in enumerate(x):
        if j > i:
            break
        else:
            contact_map_[i,j] = contact_map[i,j]

# %%
abs_sum_changes = []

for i in range(len(contact_map)):
    abs_sum_changes.append(np.sum(np.abs(contact_map[i])))

# %%
np.max(abs_sum_changes)
# Out:
# 3.0257886809046846

# %%
plt.figure(dpi=300)
plt.plot(abs_sum_changes)
plt.xlabel('Residue index')
plt.ylabel('Sum of absolute contact changes')
plt.title('ERK2 Q103M - WT')
plt.ylim((-0.4,8))
plt.show()

# %%
np.savetxt('erk2_q103m_diff_wt_abs_sum_changes', abs_sum_changes)

# %%
# 55n - q103m

# %%
contact_map = erk2_55n_q102m_wtsize - erk2_wt

contact_map_ = np.zeros(contact_map.shape)

for i, x in enumerate(contact_map):
    for j, y in enumerate(x):
        if j > i:
            break
        else:
            contact_map_[i,j] = contact_map[i,j]

# %%
abs_sum_changes = []

for i in range(len(contact_map)):
    abs_sum_changes.append(np.sum(np.abs(contact_map[i])))

# %%
np.max(abs_sum_changes)
# Out:
# 7.5594515417273902

# %%
plt.figure(dpi=300)
plt.plot(abs_sum_changes)
plt.xlabel('Residue index')
plt.ylabel('Sum of absolute contact changes')
plt.title('ERK2 55N-Q103M - WT')
plt.ylim((-0.4,8))
plt.show()

# %%
np.savetxt('erk2_55n_q103m_diff_wt_abs_sum_changes', abs_sum_changes)
